# %% [markdown]
# Scatter Plots

# %%
#Importing Libraries 

import pandas as pd
import matplotlib.pyplot as plt
from datasets import load_dataset
import ast

#Loading Data 

dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()

#Data Cleanup 

df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])
df['job_skills'] = df['job_skills'].apply(lambda x: ast.literal_eval(x) if pd.notna(x) else x)

# %%
df = df[df['job_title_short'] == 'Data Analyst']

df.head(3)
# Out:
#    job_title_short                                    job_title  \
# 1     Data Analyst                                 Data Analyst
# 12    Data Analyst  Stagiaire Data Analyst (H/F) - Lyon (69006)
# 18    Data Analyst                                 Data Analyst
#
#                     job_location                job_via  \
# 1   Guadalajara, Jalisco, Mexico       via BeBee México
# 12                  Lyon, France           via Jobijoba
# 18                Warsaw, Poland  via Praca Trabajo.org
#
#            job_schedule_type  job_work_from_home search_location  \
# 1                  Full-time               False          Mexico
# 12  Full-time and Internship               False          France
# 18                 Full-time               False          Poland
#
#        job_posted_date  job_no_degree_mention  job_health_insurance  \
# 1  2023-01-14 13:18:07                  False                 False
# 12 2023-12-22 13:24:41                  False                 False
# ...

# %%
df_exploded = df.explode('job_skills')

skill_stats = df_exploded.groupby('job_skills').agg(
    skill_count=('job_skills', 'count'), #using agg function to name new variables
    median_salary=('salary_year_avg', 'median')
)

skill_stats
# Out:
#             skill_count  median_salary
# job_skills
# airflow            2002       111175.0
# airtable             88        90000.0
# alteryx            4570       105000.0
# angular             376       109101.0
# angular.js            2            NaN
# ...                 ...            ...
# wrike                39        75000.0
# wsl                  16            NaN
# xamarin               2            NaN
# yarn                 76        99150.0
# zoom                465        81167.0
#
# [235 rows x 2 columns]

# %%
skill_stats = skill_stats.sort_values(by='skill_count', ascending=False).head(10)

skill_stats
# Out:
#             skill_count  median_salary
# job_skills
# sql               92428        92500.0
# excel             66860        84479.0
# python            57190        98500.0
# tableau           46455        95000.0
# power bi          39380        90000.0
# r                 29996        92527.5
# sas               27998        90000.0
# powerpoint        13822        85000.0
# word              13562        80000.0
# sap               11280        90000.0

# %%
skill_stats.plot(kind='scatter', x='skill_count', y='median_salary')
plt.title('Salary vs Count of Data Analyst Top 10 Skils')
plt.ylabel('Median Yearly Salary ($)')
plt.xlabel('Count of Job Postings')
plt.tight_layout()

for i, txt in enumerate(skill_stats.index):
    plt.text(skill_stats['skill_count'].iloc[i], skill_stats['median_salary'].iloc[i], txt)
    print(i,txt)
    
plt.show()

#the one issue is that the coordinates of each point are not labelled 
#so thats why I had to create a for loop using the text method in matplotlib
# Out:
# 0 sql
# 1 excel
# 2 python
# 3 tableau
# 4 power bi
# 5 r
# 6 sas
# 7 powerpoint
# 8 word
# 9 sap
